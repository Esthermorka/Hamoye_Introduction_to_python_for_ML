# %%
import pandas as pd
import numpy as np

# %%
#Load the dataset
df = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='latin-1')
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %% [markdown]
# ## Data Exploration

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
#Checking the number of rows and columns
df.shape
# Out:
# (60943, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
#Statistical Summary of year 2017
df['Y2017'].describe()
# Out:
# count     59437.000000
# mean        140.917765
# std        1671.862359
# min       -1582.000000
# 25%           0.000000
# 50%           0.100000
# 75%           9.000000
# max      190873.000000
# Name: Y2017, dtype: float64

# %%
#Number of Unique countries in the dataset
df['Area'].nunique()
# Out:
# 49

# %%
#Checking for null Values
df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
#dropping null values 
df.dropna(axis=0,inplace=True)

# %%
#Using the groupby function to get the sum of unique values in the Element column

df.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   698435   13986139      27634113
# Export Quantity                            415968    7894703      17224654
# Fat supply quantity (g/capita/day)         662095   13289323       3370752
# Feed                                       144633    2933176       6012369
# Food                                       652391   13091136      25020972
# Food supply (kcal/capita/day)              659187   13227714       3256920
# Food supply quantity (kg/capita/yr)        647542   12991502       3115350
# Import Quantity                            621285   12533807      26102372
# Losses                                     274321    5422290      10286984
# Other uses (non-food)                      208464    4179786       7859850
# Processing                                 268111    5266227      10149118
# ...

# %%
#Using the group by function to get the Sum of unique countries in Year 2017
df.groupby(['Area'])['Y2017'].sum().sort_values()
# Out:
# Area
# Sudan (former)                       0.00
# Ethiopia PDR                         0.00
# Comoros                             59.84
# Seychelles                         442.34
# Sao Tome and Principe            12662.63
# Cabo Verde                       14650.74
# Guinea-Bissau                    19095.16
# Lesotho                          21249.94
# Botswana                         22101.30
# Djibouti                         22714.91
# Gambia                           23153.17
# Gabon                            27979.64
# Liberia                          29348.20
# Namibia                          29874.89
# Central African Republic         29935.00
# Congo                            41177.68
# Togo                             49831.88
# Mauritius                        51110.83
# Eswatini                         54295.33
# Sierra Leone                     55311.33
# Chad                             71594.68
# Rwanda                           73661.69
# ...

# %%
#This Function is to get the total protein supply in each country
df[df['Area'] == 'Madagascar'].groupby(['Element']).sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                    15222     316353        625518
# Export Quantity                             11094     231950        508346
# Fat supply quantity (g/capita/day)          14319     299405         75924
# Feed                                         3870      80917        165630
# Food                                        14190     295817        565620
# Food supply (kcal/capita/day)               14319     299405         73704
# Food supply quantity (kg/capita/yr)         14190     295817         70950
# Import Quantity                             13545     282314        589155
# Losses                                       7095     148102        281765
# Other uses (non-food)                        6450     135735        257700
# Processing                                   9675     199366        384825
# ...

# %%
#To check correlation between features
df.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005850      0.003624  0.006091  0.005267
# Item Code     -0.005850   1.000000     -0.016521  0.021102  0.020226
# Element Code   0.003624  -0.016521      1.000000  0.026257  0.025632
# Y2014          0.006091   0.021102      0.026257  1.000000  0.994647
# Y2015          0.005267   0.020226      0.025632  0.994647  1.000000
# Y2016          0.005246   0.019382      0.025080  0.996081  0.995738
# Y2017          0.004979   0.020812      0.025932  0.995229  0.988047
# Y2018          0.005571   0.020527      0.025989  0.994871  0.988207
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005246  0.004979  0.005571
# Item Code     0.019382  0.020812  0.020527
# Element Code  0.025080  0.025932  0.025989
# Y2014         0.996081  0.995229  0.994871
# Y2015         0.995738  0.988047  0.988207
# Y2016         1.000000  0.992784  0.992756
# ...

# %%
#To get the sum total of unique items produced
df.groupby('Item').sum()
# Out:
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        35230     693999       1389590    2329.00    2119.00
# Alcoholic Beverages      73136    1616972       2110145  102391.11   98774.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              83742    1847142       2497151  209460.54  200675.72
# Apples and products      67924    1321585       1849486    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        75817    1474430       2179992  155038.96  158104.08
# Vegetal Products         18060     391905         90990  107145.19  107064.17
# Wheat and products       85608    1607040       2583023  232670.13  234710.51
# Wine                     63806    1269090       1707019    4494.36    4250.81
# Yams                     39196     752895       1089374  200396.96  203150.78
#
# ...

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

col = ['Age','Nationality','Overall']

df2 = pd.DataFrame(lst, columns=col, index=[1,2,3])
df2
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]
# Out:
# 'e'
